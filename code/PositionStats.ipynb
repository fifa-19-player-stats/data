# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# %matplotlib inline

import random
import urllib.request
import requests
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')

# %%
position_stats = pd.read_csv('https://raw.githubusercontent.com/fifa-19-player-stats/data/master/FIFA_clean.csv')
position_stats.head()
# Out:
#    Unnamed: 0      id               name  age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             photo nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   flag  overall  potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   club  ... gkpositioning gkreflexes releaseClause  currency  \
# 0         FC Barcelona  ...          14.0        8.0       €226.5M         €
# 1             Juventus  ...          14.0       11.0       €127.1M         €
# 2  Paris Saint-Germain  ...          15.0       11.0       €228.1M         €
# 3    Manchester United  ...          88.0       94.0       €138.6M         €
# 4      Manchester City  ...          10.0       13.0       €196.4M         €
#
#   valueAmt  valueUnit  wageAmt  wageUnit releaseClauseAmt releaseClauseUnit
# 0    110.5          M    565.0         K            226.5                 M
# 1     77.0          M    405.0         K            127.1                 M
# 2    118.5          M    290.0         K            228.1                 M
# 3     72.0          M    260.0         K            138.6                 M
# 4    102.0          M    355.0         K            196.4                 M
#
# [5 rows x 96 columns]

# %%
position_stats.columns
# Out:
# Index(['Unnamed: 0', 'id', 'name', 'age', 'photo', 'nationality', 'flag',
#        'overall', 'potential', 'club', 'clubLogo', 'value', 'wage', 'special',
#        'preferredFoot', 'internationalReputation', 'weakFoot', 'skillMoves',
#        'workRate', 'bodyType', 'realFace', 'position', 'jerseyNumber',
#        'joined', 'loanedFrom', 'contractValidUntil', 'height', 'weight', 'ls',
#        'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm',
#        'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb',
#        'lcb', 'cb', 'rcb', 'rb', 'crossing', 'finishing', 'headingaccuracy',
#        'shortpassing', 'volleys', 'dribbling', 'curve', 'fkaccuracy',
#        'longpassing', 'ballcontrol', 'acceleration', 'sprintspeed', 'agility',
#        'reactions', 'balance', 'shotpower', 'jumping', 'stamina', 'strength',
#        'longshots', 'aggression', 'interceptions', 'positioning', 'vision',
#        'penalties', 'composure', 'marking', 'standingtackle', 'slidingtackle',
#        'gkdiving', 'gkhandling', 'gkkicking', 'gkpositioning', 'gkreflexes',
#        'releaseClause', 'currency', 'valueAmt', 'valueUnit', 'wageAmt',
#        'wageUnit', 'releaseClauseAmt', 'releaseClauseUnit'],
#       dtype='object')

# %%
position_stats['position'].value_counts()
# Out:
# ST     2152
# GK     2025
# CB     1778
# CM     1394
# LB     1322
# RB     1291
# RM     1124
# LM     1095
# CAM     958
# CDM     948
# RCB     662
# LCB     648
# LCM     395
# RCM     391
# LW      381
# RW      370
# RDM     248
# LDM     243
# LS      207
# RS      203
# RWB      87
# LWB      78
# CF       74
# RAM      21
# LAM      21
# RF       16
# LF       15
# Name: position, dtype: int64

# %%
position_stats['position'] = position_stats['position'].map({'ST': 'Striker', 'GK': 'Goal Keeper', 'CB': 'Center Back', 'CM': 'Center Midfielder',
                                                            'LB': 'Left Full Back', 'RB': 'Right Full Back', 'RM': 'Right Midfielder', 'LM': 'Left Midfielder',
                                                            'CAM': 'Center Attacking Midfielder', 'CDM': 'Center Defensive Midfielder', 'RCB': 'Right Center Back', 'LCB': 'Left Center Back',
                                                            'RCM': 'Right Center Midfielder', 'LW': 'Left Winger', 'RW': 'Right Winger', 'RDM': 'Right Defensive Midfielder',
                                                            'LDM': 'Left Defensive Midfielder', 'LS': 'Left Side Player', 'RS': 'Right Side Player', 'RWB': 'Right Wing Back',
                                                            'LWB': 'Left Wing Back', 'CF': 'Center Forward', 'LAM': 'Left Attacking Midfielder', 'RAM': 'Right Attacking Midfielder',
                                                            'RF': 'Right Forward', 'LF': 'Left Forward'})
position_stats.head()
# Out:
#    Unnamed: 0      id               name  age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             photo nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   flag  overall  potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   club  ... gkpositioning gkreflexes releaseClause  currency  \
# 0         FC Barcelona  ...          14.0        8.0       €226.5M         €
# 1             Juventus  ...          14.0       11.0       €127.1M         €
# 2  Paris Saint-Germain  ...          15.0       11.0       €228.1M         €
# 3    Manchester United  ...          88.0       94.0       €138.6M         €
# 4      Manchester City  ...          10.0       13.0       €196.4M         €
#
#   valueAmt  valueUnit  wageAmt  wageUnit releaseClauseAmt releaseClauseUnit
# 0    110.5          M    565.0         K            226.5                 M
# 1     77.0          M    405.0         K            127.1                 M
# 2    118.5          M    290.0         K            228.1                 M
# 3     72.0          M    260.0         K            138.6                 M
# 4    102.0          M    355.0         K            196.4                 M
#
# [5 rows x 96 columns]

# %%
position_rank = ['position', 'id', 'name', 'crossing', 'finishing', 'headingaccuracy',
       'shortpassing', 'volleys', 'dribbling', 'curve', 'fkaccuracy',
       'longpassing', 'ballcontrol', 'acceleration', 'sprintspeed', 'agility',
       'reactions', 'balance', 'shotpower', 'jumping', 'stamina', 'strength',
       'longshots', 'aggression', 'interceptions', 'positioning', 'vision',
       'penalties', 'composure', 'marking', 'standingtackle', 'slidingtackle',
       'gkdiving', 'gkhandling', 'gkkicking', 'gkpositioning', 'gkreflexes']

skills_stats = (position_stats[position_rank])
skills_stats.head()

# position_stats['position'].value_counts()
# Out:
#                   position      id               name  crossing  finishing  \
# 0            Right Forward  158023           L. Messi      84.0       95.0
# 1                  Striker   20801  Cristiano Ronaldo      84.0       94.0
# 2              Left Winger  190871          Neymar Jr      79.0       87.0
# 3              Goal Keeper  193080             De Gea      17.0       13.0
# 4  Right Center Midfielder  192985       K. De Bruyne      93.0       82.0
#
#    headingaccuracy  shortpassing  volleys  dribbling  curve  ...  penalties  \
# 0             70.0          90.0     86.0       97.0   93.0  ...       75.0
# 1             89.0          81.0     87.0       88.0   81.0  ...       85.0
# 2             62.0          84.0     84.0       96.0   88.0  ...       81.0
# 3             21.0          50.0     13.0       18.0   21.0  ...       40.0
# 4             55.0          92.0     82.0       86.0   85.0  ...       79.0
#
#    composure  marking  standingtackle  slidingtackle  gkdiving  gkhandling  \
# 0       96.0     33.0            28.0           26.0       6.0        11.0
# 1       95.0     28.0            31.0           23.0       7.0        11.0
# 2       94.0     27.0            24.0           33.0       9.0         9.0
# 3       68.0     15.0            21.0           13.0      90.0        85.0
# 4       88.0     68.0            58.0           51.0      15.0        13.0
#
#    gkkicking  gkpositioning  gkreflexes
# 0       15.0           14.0         8.0
# 1       15.0           14.0        11.0
# 2       15.0           15.0        11.0
# 3       87.0           88.0        94.0
# 4        5.0           10.0        13.0
#
# [5 rows x 37 columns]

# %%
skills_stats.set_index(['position', 'id'], inplace=True)
skills_stats.head()
# Out:
#                                              name  crossing  finishing  \
# position                id
# Right Forward           158023           L. Messi      84.0       95.0
# Striker                 20801   Cristiano Ronaldo      84.0       94.0
# Left Winger             190871          Neymar Jr      79.0       87.0
# Goal Keeper             193080             De Gea      17.0       13.0
# Right Center Midfielder 192985       K. De Bruyne      93.0       82.0
#
#                                 headingaccuracy  shortpassing  volleys  \
# position                id
# Right Forward           158023             70.0          90.0     86.0
# Striker                 20801              89.0          81.0     87.0
# Left Winger             190871             62.0          84.0     84.0
# Goal Keeper             193080             21.0          50.0     13.0
# Right Center Midfielder 192985             55.0          92.0     82.0
#
#                                 dribbling  curve  fkaccuracy  longpassing  \
# position                id
# Right Forward           158023       97.0   93.0        94.0         87.0
# Striker                 20801        88.0   81.0        76.0         77.0
# Left Winger             190871       96.0   88.0        87.0         78.0
# Goal Keeper             193080       18.0   21.0        19.0         51.0
# Right Center Midfielder 192985       86.0   85.0        83.0         91.0
#
#                                 ...  penalties  composure  marking  \
# position                id      ...
# Right Forward           158023  ...       75.0       96.0     33.0
# Striker                 20801   ...       85.0       95.0     28.0
# Left Winger             190871  ...       81.0       94.0     27.0
# Goal Keeper             193080  ...       40.0       68.0     15.0
# Right Center Midfielder 192985  ...       79.0       88.0     68.0
#
#                                 standingtackle  slidingtackle  gkdiving  \
# position                id
# Right Forward           158023            28.0           26.0       6.0
# Striker                 20801             31.0           23.0       7.0
# Left Winger             190871            24.0           33.0       9.0
# Goal Keeper             193080            21.0           13.0      90.0
# Right Center Midfielder 192985            58.0           51.0      15.0
#
#                                 gkhandling  gkkicking  gkpositioning  \
# position                id
# Right Forward           158023        11.0       15.0           14.0
# Striker                 20801         11.0       15.0           14.0
# Left Winger             190871         9.0       15.0           15.0
# Goal Keeper             193080        85.0       87.0           88.0
# Right Center Midfielder 192985        13.0        5.0           10.0
#
#                                 gkreflexes
# position                id
# Right Forward           158023         8.0
# Striker                 20801         11.0
# Left Winger             190871        11.0
# Goal Keeper             193080        94.0
# Right Center Midfielder 192985        13.0
#
# [5 rows x 35 columns]

# %%
right_forward = skills_stats.loc['Right Forward']
right_forward.head()
# Out:
#                name  crossing  finishing  headingaccuracy  shortpassing  \
# id
# 158023     L. Messi      84.0       95.0             70.0          90.0
# 175943   D. Mertens      77.0       86.0             35.0          82.0
# 172114    D. Valeri      78.0       80.0             70.0          79.0
# 150516  L. Podolski      75.0       77.0             66.0          76.0
# 201313     C. Ciano      72.0       70.0             60.0          73.0
#
#         volleys  dribbling  curve  fkaccuracy  longpassing  ...  penalties  \
# id                                                          ...
# 158023     86.0       97.0   93.0        94.0         87.0  ...       75.0
# 175943     70.0       91.0   82.0        79.0         74.0  ...       79.0
# 172114     75.0       78.0   80.0        79.0         76.0  ...       79.0
# 150516     88.0       78.0   80.0        75.0         67.0  ...       83.0
# 201313     67.0       76.0   75.0        76.0         70.0  ...       70.0
#
#         composure  marking  standingtackle  slidingtackle  gkdiving  \
# id
# 158023       96.0     33.0            28.0           26.0       6.0
# 175943       81.0     25.0            40.0           40.0       7.0
# 172114       83.0     39.0            40.0           30.0      15.0
# 150516       79.0     54.0            39.0           39.0      10.0
# 201313       74.0     24.0            23.0           20.0       9.0
#
#         gkhandling  gkkicking  gkpositioning  gkreflexes
# id
# 158023        11.0       15.0           14.0         8.0
# 175943        10.0        8.0           10.0         4.0
# 172114        15.0        8.0           10.0        12.0
# 150516         9.0       16.0            9.0         9.0
# 201313        12.0        9.0            9.0         7.0
#
# [5 rows x 35 columns]

# %%
left_forward = skills_stats.loc['Left Forward']
left_forward.head()
# Out:
#                   name  crossing  finishing  headingaccuracy  shortpassing  \
# id
# 183277       E. Hazard      81.0       84.0             61.0          89.0
# 211110       P. Dybala      82.0       84.0             68.0          87.0
# 41             Iniesta      77.0       70.0             54.0          90.0
# 198164  Jonathan Viera      75.0       78.0             41.0          84.0
# 190577       S. Blanco      69.0       69.0             66.0          76.0
#
#         volleys  dribbling  curve  fkaccuracy  longpassing  ...  penalties  \
# id                                                          ...
# 183277     80.0       95.0   83.0        79.0         83.0  ...       86.0
# 211110     88.0       92.0   88.0        88.0         75.0  ...       86.0
# 41         74.0       90.0   80.0        70.0         85.0  ...       71.0
# 198164     65.0       84.0   80.0        76.0         78.0  ...       74.0
# 190577     76.0       75.0   64.0        60.0         70.0  ...       61.0
#
#         composure  marking  standingtackle  slidingtackle  gkdiving  \
# id
# 183277       91.0     34.0            27.0           22.0      11.0
# 211110       84.0     23.0            20.0           20.0       5.0
# 41           89.0     67.0            57.0           56.0       6.0
# 198164       80.0     56.0            68.0           55.0      16.0
# 190577       65.0     30.0            22.0           32.0       9.0
#
#         gkhandling  gkkicking  gkpositioning  gkreflexes
# id
# 183277        12.0        6.0            8.0         8.0
# 211110         4.0        4.0            5.0         8.0
# 41            13.0        6.0           13.0         7.0
# 198164        16.0        9.0           14.0         9.0
# 190577         7.0        9.0           13.0        12.0
#
# [5 rows x 35 columns]

# %%
striker = skills_stats.loc['Striker']
striker.head()
# Out:
#                      name  crossing  finishing  headingaccuracy  shortpassing  \
# id
# 20801   Cristiano Ronaldo      84.0       94.0             89.0          81.0
# 188545     R. Lewandowski      62.0       91.0             85.0          83.0
# 202126            H. Kane      75.0       94.0             85.0          80.0
# 153079          S. Agüero      70.0       93.0             77.0          81.0
# 173731            G. Bale      87.0       86.0             84.0          85.0
#
#         volleys  dribbling  curve  fkaccuracy  longpassing  ...  penalties  \
# id                                                          ...
# 20801      87.0       88.0   81.0        76.0         77.0  ...       85.0
# 188545     89.0       85.0   77.0        86.0         65.0  ...       88.0
# 202126     84.0       80.0   78.0        68.0         82.0  ...       90.0
# 153079     85.0       89.0   82.0        73.0         64.0  ...       83.0
# 173731     85.0       87.0   90.0        87.0         80.0  ...       76.0
#
#         composure  marking  standingtackle  slidingtackle  gkdiving  \
# id
# 20801        95.0     28.0            31.0           23.0       7.0
# 188545       86.0     34.0            42.0           19.0      15.0
# 202126       89.0     56.0            36.0           38.0       8.0
# 153079       90.0     30.0            20.0           12.0      13.0
# 173731       86.0     54.0            55.0           52.0      15.0
#
#         gkhandling  gkkicking  gkpositioning  gkreflexes
# id
# 20801         11.0       15.0           14.0        11.0
# 188545         6.0       12.0            8.0        10.0
# 202126        10.0       11.0           14.0        11.0
# 153079        15.0        6.0           11.0        14.0
# 173731        15.0       11.0            5.0         6.0
#
# [5 rows x 35 columns]

# %%
left_winger = skills_stats.loc['Left Winger']
left_winger.head()
# Out:
#               name  crossing  finishing  headingaccuracy  shortpassing  \
# id
# 190871   Neymar Jr      79.0       87.0             62.0          84.0
# 198219  L. Insigne      86.0       77.0             56.0          85.0
# 197781        Isco      75.0       79.0             55.0          89.0
# 189242    Coutinho      79.0       79.0             48.0          88.0
# 222492     L. Sané      83.0       81.0             72.0          79.0
#
#         volleys  dribbling  curve  fkaccuracy  longpassing  ...  penalties  \
# id                                                          ...
# 190871     84.0       96.0   88.0        87.0         78.0  ...       81.0
# 198219     74.0       90.0   87.0        77.0         78.0  ...       61.0
# 197781     65.0       94.0   88.0        76.0         83.0  ...       76.0
# 189242     75.0       91.0   91.0        86.0         83.0  ...       70.0
# 222492     85.0       88.0   82.0        68.0         64.0  ...       71.0
#
#         composure  marking  standingtackle  slidingtackle  gkdiving  \
# id
# 190871       94.0     27.0            24.0           33.0       9.0
# 198219       83.0     51.0            24.0           22.0       8.0
# 197781       86.0     60.0            64.0           51.0      10.0
# 189242       85.0     55.0            54.0           47.0      12.0
# 222492       78.0     36.0            32.0           35.0       8.0
#
#         gkhandling  gkkicking  gkpositioning  gkreflexes
# id
# 190871         9.0       15.0           15.0        11.0
# 198219         4.0       14.0            9.0        10.0
# 197781         8.0       12.0           15.0         6.0
# 189242         7.0        9.0           14.0         6.0
# 222492        12.0        9.0            9.0        14.0
#
# [5 rows x 35 columns]

# %%
keeper = skills_stats.loc['Goal Keeper']
keeper.head()
# Out:
#                  name  crossing  finishing  headingaccuracy  shortpassing  \
# id
# 193080         De Gea      17.0       13.0             21.0          50.0
# 200389       J. Oblak      13.0       11.0             15.0          29.0
# 192448  M. ter Stegen      15.0       14.0             11.0          36.0
# 192119    T. Courtois      14.0       14.0             13.0          33.0
# 167495       M. Neuer      15.0       13.0             25.0          55.0
#
#         volleys  dribbling  curve  fkaccuracy  longpassing  ...  penalties  \
# id                                                          ...
# 193080     13.0       18.0   21.0        19.0         51.0  ...       40.0
# 200389     13.0       12.0   13.0        14.0         26.0  ...       11.0
# 192448     14.0       17.0   18.0        12.0         42.0  ...       25.0
# 192119     12.0       13.0   19.0        20.0         35.0  ...       27.0
# 167495     11.0       30.0   14.0        11.0         59.0  ...       47.0
#
#         composure  marking  standingtackle  slidingtackle  gkdiving  \
# id
# 193080       68.0     15.0            21.0           13.0      90.0
# 200389       70.0     27.0            12.0           18.0      86.0
# 192448       69.0     25.0            13.0           10.0      87.0
# 192119       66.0     20.0            18.0           16.0      85.0
# 167495       70.0     17.0            10.0           11.0      90.0
#
#         gkhandling  gkkicking  gkpositioning  gkreflexes
# id
# 193080        85.0       87.0           88.0        94.0
# 200389        92.0       78.0           88.0        89.0
# 192448        85.0       88.0           85.0        90.0
# 192119        91.0       72.0           86.0        88.0
# 167495        86.0       91.0           87.0        87.0
#
# [5 rows x 35 columns]

# %%
keeper.columns
# Out:
# Index(['name', 'crossing', 'finishing', 'headingaccuracy', 'shortpassing',
#        'volleys', 'dribbling', 'curve', 'fkaccuracy', 'longpassing',
#        'ballcontrol', 'acceleration', 'sprintspeed', 'agility', 'reactions',
#        'balance', 'shotpower', 'jumping', 'stamina', 'strength', 'longshots',
#        'aggression', 'interceptions', 'positioning', 'vision', 'penalties',
#        'composure', 'marking', 'standingtackle', 'slidingtackle', 'gkdiving',
#        'gkhandling', 'gkkicking', 'gkpositioning', 'gkreflexes'],
#       dtype='object')

# %%
# Formula for Goal Keeper ratings. Weighted average of a weighted average.
keeper_rating1 = round((0.15*keeper.gkdiving) + (0.25*keeper.gkhandling) + (0.1*keeper.gkkicking) + (0.2*keeper.gkpositioning) + (0.2*keeper.gkreflexes) + (0.1*keeper.reactions), 2)
keeper_rating2 = round((0.2*keeper.fkaccuracy) + (0.1*keeper.jumping) + (0.15*keeper.ballcontrol) + (0.15*keeper.dribbling) + (0.3*keeper.shortpassing) + (0.1*keeper.positioning), 2)
keeper_rating3 = round((0.3*keeper.agility) + (0.15*keeper.balance) + (0.1*keeper.vision) + (0.3*keeper.aggression) + (0.15*keeper.strength), 2)
keeper_rating4 = round((0.15*keeper.interceptions) + (0.2*keeper.stamina) + (0.2*keeper.composure) + (0.05*keeper.penalties) + (0.25*keeper.slidingtackle) + (0.15*keeper.curve), 2)
keeper_total = round((0.4*keeper_rating1) + (0.3*keeper_rating2) + (0.2*keeper_rating3) + (0.1*keeper_rating4), 2)
best_keeper = pd.DataFrame(keeper_total)
best_keeper.head()
# Out:
#             0
# id
# 193080  60.21
# 200389  56.88
# 192448  55.77
# 192119  55.08
# 167495  59.79

# %%
# creating a rank column and passing the returned rank series
nums = []
for i in range(1,len(best_keeper)+1):
    nums.append(i)
best_keeper['Rank'] = nums
best_keeper.columns = ['Score', 'Rank']
best_keeper.tail()
# Out:
#         Score  Rank
# id
# 243158  30.83  2021
# 221669  36.29  2022
# 53748   32.22  2023
# 245862  31.57  2024
# 242844  31.88  2025

# %%
center_back = skills_stats.loc['Center Back']
center_back.head()
# Out:
#                name  crossing  finishing  headingaccuracy  shortpassing  \
# id
# 182493     D. Godín      55.0       42.0             92.0          79.0
# 205600    S. Umtiti      69.0       51.0             79.0          81.0
# 177509   M. Benatia      45.0       47.0             83.0          65.0
# 192366  N. Otamendi      52.0       54.0             85.0          75.0
# 171919        Naldo      45.0       57.0             94.0          76.0
#
#         volleys  dribbling  curve  fkaccuracy  longpassing  ...  penalties  \
# id                                                          ...
# 182493     47.0       53.0   49.0        51.0         70.0  ...       50.0
# 205600     70.0       69.0   72.0        62.0         73.0  ...       61.0
# 177509     44.0       64.0   34.0        27.0         65.0  ...       41.0
# 192366     57.0       51.0   50.0        39.0         72.0  ...       45.0
# 171919     60.0       60.0   52.0        76.0         70.0  ...       60.0
#
#         composure  marking  standingtackle  slidingtackle  gkdiving  \
# id
# 182493       82.0     90.0            89.0           89.0       6.0
# 205600       82.0     90.0            89.0           86.0      15.0
# 177509       82.0     89.0            87.0           85.0       7.0
# 192366       80.0     83.0            85.0           84.0      12.0
# 171919       84.0     86.0            88.0           85.0      14.0
#
#         gkhandling  gkkicking  gkpositioning  gkreflexes
# id
# 182493         8.0       15.0            5.0        15.0
# 205600        10.0       14.0           12.0        15.0
# 177509         4.0        8.0            7.0        11.0
# 192366         5.0        8.0           11.0        12.0
# 171919        10.0       14.0            8.0        14.0
#
# [5 rows x 35 columns]

# %%
center_midfielder = skills_stats.loc['Center Midfielder']
center_midfielder.head()
# Out:
#                        name  crossing  finishing  headingaccuracy  \
# id
# 189509               Thiago      72.0       69.0             54.0
# 223848  S. Milinković-Savić      64.0       80.0             86.0
# 205498             Jorginho      75.0       57.0             56.0
# 186942          I. Gündoğan      74.0       73.0             50.0
# 220971             N. Keïta      62.0       74.0             42.0
#
#         shortpassing  volleys  dribbling  curve  fkaccuracy  longpassing  ...  \
# id                                                                        ...
# 189509          90.0     90.0       90.0   85.0        77.0         87.0  ...
# 223848          85.0     74.0       86.0   78.0        75.0         85.0  ...
# 205498          89.0     71.0       82.0   75.0        76.0         87.0  ...
# 186942          88.0     75.0       85.0   81.0        74.0         83.0  ...
# 220971          88.0     71.0       88.0   64.0        70.0         78.0  ...
#
#         penalties  composure  marking  standingtackle  slidingtackle  \
# id
# 189509       75.0       85.0     67.0            63.0           65.0
# 223848       56.0       82.0     75.0            77.0           72.0
# 205498       84.0       79.0     63.0            78.0           70.0
# 186942       76.0       87.0     73.0            68.0           64.0
# 220971       58.0       79.0     68.0            62.0           61.0
#
#         gkdiving  gkhandling  gkkicking  gkpositioning  gkreflexes
# id
# 189509       6.0        11.0        7.0            9.0        13.0
# 223848       7.0        10.0        7.0           16.0         7.0
# 205498      14.0         7.0       13.0           14.0         8.0
# 186942      11.0        14.0        5.0            5.0        13.0
# 220971       7.0        14.0       15.0           14.0         9.0
#
# [5 rows x 35 columns]

# %%
left_full_back = skills_stats.loc['Left Full Back']
left_full_back.head()
# Out:
#                name  crossing  finishing  headingaccuracy  shortpassing  \
# id
# 176676      Marcelo      90.0       70.0             75.0          84.0
# 189332   Jordi Alba      87.0       73.0             70.0          84.0
# 191043  Alex Sandro      84.0       55.0             76.0          81.0
# 197445     D. Alaba      81.0       63.0             75.0          82.0
# 164169  Filipe Luís      86.0       59.0             72.0          80.0
#
#         volleys  dribbling  curve  fkaccuracy  longpassing  ...  penalties  \
# id                                                          ...
# 176676     54.0       90.0   85.0        67.0         76.0  ...       59.0
# 189332     60.0       80.0   80.0        63.0         74.0  ...       59.0
# 191043     68.0       80.0   78.0        59.0         71.0  ...       60.0
# 197445     68.0       79.0   78.0        84.0         80.0  ...       80.0
# 164169     56.0       77.0   74.0        75.0         77.0  ...       65.0
#
#         composure  marking  standingtackle  slidingtackle  gkdiving  \
# id
# 176676       86.0     71.0            85.0           86.0      12.0
# 189332       79.0     72.0            84.0           85.0      13.0
# 191043       82.0     81.0            84.0           84.0       7.0
# 197445       79.0     80.0            82.0           80.0       5.0
# 164169       88.0     78.0            84.0           86.0      11.0
#
#         gkhandling  gkkicking  gkpositioning  gkreflexes
# id
# 176676         5.0        5.0            5.0         9.0
# 189332        15.0       13.0            6.0        13.0
# 191043         7.0        9.0           12.0         5.0
# 197445         7.0       14.0           15.0         9.0
# 164169        15.0        9.0            9.0         5.0
#
# [5 rows x 35 columns]

# %%
right_full_back = skills_stats.loc['Right Full Back']
right_full_back.head()
# Out:
#                  name  crossing  finishing  headingaccuracy  shortpassing  \
# id
# 184432    Azpilicueta      81.0       46.0             76.0          81.0
# 204963       Carvajal      83.0       41.0             70.0          81.0
# 188377      K. Walker      81.0       51.0             74.0          78.0
# 199564  Sergi Roberto      85.0       63.0             72.0          86.0
# 177457      L. Bender      69.0       59.0             78.0          79.0
#
#         volleys  dribbling  curve  fkaccuracy  longpassing  ...  penalties  \
# id                                                          ...
# 184432     51.0       69.0   68.0        58.0         80.0  ...       66.0
# 204963     34.0       76.0   72.0        47.0         71.0  ...       45.0
# 188377     57.0       79.0   76.0        71.0         67.0  ...       63.0
# 199564     50.0       78.0   74.0        60.0         78.0  ...       57.0
# 177457     57.0       72.0   49.0        47.0         74.0  ...       52.0
#
#         composure  marking  standingtackle  slidingtackle  gkdiving  \
# id
# 184432       78.0     88.0            90.0           86.0      13.0
# 204963       77.0     83.0            83.0           85.0      13.0
# 188377       75.0     78.0            84.0           83.0      12.0
# 199564       76.0     75.0            83.0           83.0      14.0
# 177457       83.0     88.0            86.0           82.0      12.0
#
#         gkhandling  gkkicking  gkpositioning  gkreflexes
# id
# 184432         9.0       10.0            6.0         5.0
# 204963        13.0       15.0            9.0        15.0
# 188377         6.0       16.0           15.0         8.0
# 199564        16.0       11.0           15.0        10.0
# 177457         6.0        7.0           12.0         7.0
#
# [5 rows x 35 columns]

# %%
right_midfielder = skills_stats.loc['Right Midfielder']
right_midfielder.head()
# Out:
#                  name  crossing  finishing  headingaccuracy  shortpassing  \
# id
# 231747      K. Mbappé      77.0       88.0             77.0          82.0
# 209331       M. Salah      78.0       90.0             59.0          82.0
# 204970     F. Thauvin      83.0       81.0             75.0          83.0
# 185020  José Callejón      82.0       78.0             65.0          80.0
# 183898    A. Di María      83.0       72.0             51.0          82.0
#
#         volleys  dribbling  curve  fkaccuracy  longpassing  ...  penalties  \
# id                                                          ...
# 231747     78.0       90.0   77.0        63.0         73.0  ...       70.0
# 209331     73.0       89.0   83.0        60.0         72.0  ...       61.0
# 204970     74.0       85.0   86.0        72.0         76.0  ...       74.0
# 185020     84.0       82.0   73.0        65.0         51.0  ...       62.0
# 183898     77.0       86.0   84.0        82.0         79.0  ...       73.0
#
#         composure  marking  standingtackle  slidingtackle  gkdiving  \
# id
# 231747       86.0     34.0            34.0           32.0      13.0
# 209331       91.0     38.0            43.0           41.0      14.0
# 204970       82.0     46.0            29.0           31.0       8.0
# 185020       79.0     64.0            32.0           32.0       8.0
# 183898       82.0     35.0            59.0           56.0      10.0
#
#         gkhandling  gkkicking  gkpositioning  gkreflexes
# id
# 231747         5.0        7.0           11.0         6.0
# 209331        14.0        9.0           11.0        14.0
# 204970        11.0       14.0           10.0         9.0
# 185020         5.0       14.0           11.0        11.0
# 183898         7.0       11.0           12.0        11.0
#
# [5 rows x 35 columns]

# %%
left_midfielder = skills_stats.loc['Left Midfielder']
left_midfielder.head()
# Out:
#                  name  crossing  finishing  headingaccuracy  shortpassing  \
# id
# 188567  P. Aubameyang      77.0       88.0             79.0          77.0
# 208722        S. Mané      73.0       84.0             62.0          79.0
# 190483  Douglas Costa      84.0       67.0             50.0          84.0
# 188350        M. Reus      79.0       87.0             49.0          86.0
# 193747           Koke      86.0       72.0             61.0          90.0
#
#         volleys  dribbling  curve  fkaccuracy  longpassing  ...  penalties  \
# id                                                          ...
# 188567     86.0       79.0   80.0        74.0         64.0  ...       76.0
# 208722     71.0       87.0   74.0        64.0         71.0  ...       71.0
# 190483     76.0       92.0   84.0        78.0         68.0  ...       77.0
# 188350     90.0       87.0   89.0        84.0         75.0  ...       89.0
# 193747     56.0       82.0   85.0        76.0         89.0  ...       59.0
#
#         composure  marking  standingtackle  slidingtackle  gkdiving  \
# id
# 188567       86.0     27.0            25.0           36.0       6.0
# 208722       80.0     42.0            42.0           38.0      10.0
# 190483       84.0     45.0            38.0           34.0      13.0
# 188350       84.0     47.0            36.0           45.0      12.0
# 193747       78.0     80.0            69.0           51.0      14.0
#
#         gkhandling  gkkicking  gkpositioning  gkreflexes
# id
# 188567         9.0       15.0            9.0         9.0
# 208722        10.0       15.0            7.0        14.0
# 190483        15.0        9.0           12.0         5.0
# 188350        12.0       13.0           13.0        11.0
# 193747        12.0        5.0           10.0        13.0
#
# [5 rows x 35 columns]

# %%
center_attacking_midfielder = skills_stats.loc['Center Attacking Midfielder']
center_attacking_midfielder.head()
# Out:
#                    name  crossing  finishing  headingaccuracy  shortpassing  \
# id
# 194765     A. Griezmann      82.0       90.0             84.0          83.0
# 190460       C. Eriksen      88.0       80.0             52.0          91.0
# 201942  Roberto Firmino      72.0       87.0             77.0          86.0
# 189596        T. Müller      79.0       87.0             82.0          83.0
# 176635          M. Özil      83.0       73.0             54.0          89.0
#
#         volleys  dribbling  curve  fkaccuracy  longpassing  ...  penalties  \
# id                                                          ...
# 194765     87.0       88.0   84.0        78.0         76.0  ...       79.0
# 190460     77.0       84.0   86.0        87.0         88.0  ...       67.0
# 201942     81.0       87.0   80.0        65.0         75.0  ...       72.0
# 189596     84.0       75.0   81.0        59.0         72.0  ...       60.0
# 176635     80.0       84.0   84.0        77.0         82.0  ...       67.0
#
#         composure  marking  standingtackle  slidingtackle  gkdiving  \
# id
# 194765       87.0     59.0            47.0           48.0      14.0
# 190460       88.0     59.0            57.0           22.0       9.0
# 201942       87.0     60.0            64.0           42.0       8.0
# 189596       83.0     44.0            41.0           44.0       6.0
# 176635       82.0     24.0            16.0           19.0       6.0
#
#         gkhandling  gkkicking  gkpositioning  gkreflexes
# id
# 194765         8.0       14.0           13.0        14.0
# 190460        14.0        7.0            7.0         6.0
# 201942        11.0        9.0            6.0        10.0
# 189596         7.0       11.0           14.0        14.0
# 176635        14.0       10.0            6.0        14.0
#
# [5 rows x 35 columns]

# %%
center_defensive_midfielder = skills_stats.loc['Center Defensive Midfielder']
center_defensive_midfielder.head()
# Out:
#                    name  crossing  finishing  headingaccuracy  shortpassing  \
# id
# 189511  Sergio Busquets      62.0       67.0             68.0          89.0
# 200145         Casemiro      52.0       59.0             76.0          85.0
# 180206        M. Pjanić      80.0       60.0             60.0          89.0
# 135507      Fernandinho      68.0       69.0             63.0          85.0
# 209499          Fabinho      79.0       66.0             75.0          83.0
#
#         volleys  dribbling  curve  fkaccuracy  longpassing  ...  penalties  \
# id                                                          ...
# 189511     44.0       80.0   66.0        68.0         82.0  ...       60.0
# 200145     53.0       69.0   59.0        74.0         82.0  ...       66.0
# 180206     72.0       86.0   86.0        92.0         85.0  ...       79.0
# 135507     74.0       77.0   70.0        72.0         81.0  ...       61.0
# 209499     47.0       76.0   71.0        53.0         78.0  ...       91.0
#
#         composure  marking  standingtackle  slidingtackle  gkdiving  \
# id
# 189511       90.0     90.0            86.0           80.0       5.0
# 200145       84.0     88.0            90.0           87.0      13.0
# 180206       86.0     75.0            74.0           70.0       7.0
# 135507       79.0     85.0            85.0           80.0      12.0
# 209499       84.0     83.0            86.0           84.0      13.0
#
#         gkhandling  gkkicking  gkpositioning  gkreflexes
# id
# 189511         8.0       13.0            9.0        13.0
# 200145        14.0       16.0           12.0        12.0
# 180206         7.0       13.0            7.0         8.0
# 135507        11.0        5.0           13.0         7.0
# 209499        12.0        6.0            8.0         8.0
#
# [5 rows x 35 columns]

# %%
left_center_back = skills_stats.loc['Left Center Back']
left_center_back.head()
# Out:
#                  name  crossing  finishing  headingaccuracy  shortpassing  \
# id
# 138956   G. Chiellini      58.0       33.0             83.0          59.0
# 178603     M. Hummels      64.0       55.0             87.0          81.0
# 201024   K. Koulibaly      30.0       19.0             81.0          66.0
# 172871  J. Vertonghen      68.0       56.0             80.0          79.0
# 203376    V. van Dijk      53.0       52.0             82.0          76.0
#
#         volleys  dribbling  curve  fkaccuracy  longpassing  ...  penalties  \
# id                                                          ...
# 138956     45.0       58.0   60.0        31.0         59.0  ...       50.0
# 178603     60.0       68.0   65.0        53.0         85.0  ...       68.0
# 201024     14.0       66.0   28.0        28.0         56.0  ...       33.0
# 172871     52.0       71.0   58.0        73.0         74.0  ...       66.0
# 203376     45.0       70.0   60.0        70.0         78.0  ...       62.0
#
#         composure  marking  standingtackle  slidingtackle  gkdiving  \
# id
# 138956       84.0     93.0            93.0           90.0       3.0
# 178603       91.0     88.0            90.0           88.0      15.0
# 201024       78.0     91.0            88.0           86.0       7.0
# 172871       83.0     90.0            87.0           88.0       6.0
# 203376       83.0     88.0            89.0           84.0      13.0
#
#         gkhandling  gkkicking  gkpositioning  gkreflexes
# id
# 138956         3.0        2.0            4.0         3.0
# 178603         6.0       10.0            5.0         6.0
# 201024        11.0        7.0           13.0         5.0
# 172871        10.0        9.0           12.0         7.0
# 203376        10.0       13.0           11.0        11.0
#
# [5 rows x 35 columns]

# %%
right_center_midfielder = skills_stats.loc['Right Center Midfielder']
right_center_midfielder.head()
# Out:
#                 name  crossing  finishing  headingaccuracy  shortpassing  \
# id
# 192985  K. De Bruyne      93.0       82.0             55.0          92.0
# 177003     L. Modrić      86.0       72.0             55.0          93.0
# 168651    I. Rakitić      84.0       83.0             58.0          87.0
# 212622    J. Kimmich      90.0       66.0             74.0          85.0
# 208421          Saúl      69.0       78.0             83.0          85.0
#
#         volleys  dribbling  curve  fkaccuracy  longpassing  ...  penalties  \
# id                                                          ...
# 192985     82.0       86.0   85.0        83.0         91.0  ...       79.0
# 177003     76.0       90.0   85.0        78.0         88.0  ...       82.0
# 168651     80.0       84.0   88.0        84.0         90.0  ...       82.0
# 212622     61.0       80.0   81.0        61.0         80.0  ...       44.0
# 208421     76.0       83.0   72.0        60.0         83.0  ...       55.0
#
#         composure  marking  standingtackle  slidingtackle  gkdiving  \
# id
# 192985       88.0     68.0            58.0           51.0      15.0
# 177003       84.0     60.0            76.0           73.0      13.0
# 168651       81.0     72.0            74.0           70.0      14.0
# 212622       82.0     75.0            81.0           79.0       8.0
# 208421       83.0     77.0            79.0           76.0       7.0
#
#         gkhandling  gkkicking  gkpositioning  gkreflexes
# id
# 192985        13.0        5.0           10.0        13.0
# 177003         9.0        7.0           14.0         9.0
# 168651        11.0       12.0            5.0         9.0
# 212622        15.0        7.0           15.0        15.0
# 208421        13.0       12.0           10.0         9.0
#
# [5 rows x 35 columns]

# %%
right_winger = skills_stats.loc['Right Winger']
right_winger.head()
# Out:
#                   name  crossing  finishing  headingaccuracy  shortpassing  \
# id
# 218667  Bernardo Silva      85.0       75.0             51.0          85.0
# 202652     R. Sterling      77.0       77.0             38.0          84.0
# 220834   Marco Asensio      82.0       82.0             50.0          83.0
# 204485       R. Mahrez      81.0       80.0             48.0          82.0
# 184941      A. Sánchez      77.0       80.0             73.0          77.0
#
#         volleys  dribbling  curve  fkaccuracy  longpassing  ...  penalties  \
# id                                                          ...
# 218667     69.0       92.0   83.0        67.0         79.0  ...       68.0
# 202652     67.0       88.0   70.0        63.0         69.0  ...       69.0
# 220834     79.0       86.0   83.0        76.0         82.0  ...       62.0
# 204485     72.0       91.0   84.0        78.0         76.0  ...       73.0
# 184941     83.0       87.0   79.0        78.0         75.0  ...       77.0
#
#         composure  marking  standingtackle  slidingtackle  gkdiving  \
# id
# 218667       85.0     49.0            44.0           35.0       9.0
# 202652       77.0     47.0            58.0           54.0      15.0
# 220834       83.0     40.0            42.0           39.0      13.0
# 204485       86.0     45.0            31.0           18.0      15.0
# 184941       84.0     38.0            44.0           35.0      10.0
#
#         gkhandling  gkkicking  gkpositioning  gkreflexes
# id
# 218667        10.0       14.0           12.0         9.0
# 202652        12.0       12.0           15.0         9.0
# 220834         9.0        6.0           12.0        10.0
# 204485         9.0       13.0           11.0         6.0
# 184941        10.0       15.0           12.0        13.0
#
# [5 rows x 35 columns]

# %%
right_defensive_midfielder = skills_stats.loc['Right Defensive Midfielder']
right_defensive_midfielder.head()
# Out:
#                 name  crossing  finishing  headingaccuracy  shortpassing  \
# id
# 195864      P. Pogba      80.0       73.0             73.0          86.0
# 190584  Illarramendi      68.0       72.0             51.0          86.0
# 193474      I. Gueye      60.0       50.0             69.0          80.0
# 53302    D. De Rossi      57.0       50.0             81.0          81.0
# 183498     M. Parolo      70.0       70.0             75.0          80.0
#
#         volleys  dribbling  curve  fkaccuracy  longpassing  ...  penalties  \
# id                                                          ...
# 195864     85.0       87.0   84.0        82.0         90.0  ...       81.0
# 190584     58.0       78.0   76.0        68.0         82.0  ...       50.0
# 193474     32.0       75.0   33.0        61.0         72.0  ...       54.0
# 53302      74.0       64.0   62.0        71.0         80.0  ...       75.0
# 183498     76.0       75.0   67.0        55.0         83.0  ...       45.0
#
#         composure  marking  standingtackle  slidingtackle  gkdiving  \
# id
# 195864       87.0     66.0            70.0           68.0       5.0
# 190584       79.0     69.0            83.0           80.0      15.0
# 193474       80.0     84.0            89.0           84.0       8.0
# 53302        87.0     90.0            82.0           80.0      10.0
# 183498       78.0     78.0            80.0           82.0      13.0
#
#         gkhandling  gkkicking  gkpositioning  gkreflexes
# id
# 195864         6.0        2.0            4.0         3.0
# 190584         7.0       11.0           14.0        12.0
# 193474         6.0        8.0           12.0        13.0
# 53302          7.0       13.0           10.0         9.0
# 183498         9.0        6.0            7.0         9.0
#
# [5 rows x 35 columns]

# %%
left_defensive_midfielder = skills_stats.loc['Left Defensive Midfielder']
left_defensive_midfielder.head()
# Out:
#                name  crossing  finishing  headingaccuracy  shortpassing  \
# id
# 215914     N. Kanté      68.0       65.0             54.0          86.0
# 187961     Paulinho      64.0       81.0             85.0          84.0
# 207865   Marquinhos      72.0       33.0             80.0          81.0
# 176266  Lucas Leiva      63.0       62.0             72.0          82.0
# 228702   F. de Jong      75.0       52.0             64.0          87.0
#
#         volleys  dribbling  curve  fkaccuracy  longpassing  ...  penalties  \
# id                                                          ...
# 215914     56.0       79.0   49.0        49.0         81.0  ...       54.0
# 187961     75.0       82.0   66.0        72.0         80.0  ...       71.0
# 207865     31.0       59.0   49.0        32.0         78.0  ...       31.0
# 176266     59.0       77.0   74.0        47.0         81.0  ...       61.0
# 228702     64.0       86.0   74.0        61.0         82.0  ...       45.0
#
#         composure  marking  standingtackle  slidingtackle  gkdiving  \
# id
# 215914       85.0     90.0            91.0           85.0      15.0
# 187961       80.0     75.0            81.0           73.0      16.0
# 207865       79.0     85.0            87.0           87.0       6.0
# 176266       86.0     82.0            82.0           78.0      10.0
# 228702       86.0     69.0            73.0           70.0       7.0
#
#         gkhandling  gkkicking  gkpositioning  gkreflexes
# id
# 215914        12.0       10.0            7.0        10.0
# 187961        16.0       11.0            6.0         8.0
# 207865         6.0       12.0           10.0        13.0
# 176266         8.0        8.0            5.0         6.0
# 228702        13.0       10.0           10.0         9.0
#
# [5 rows x 35 columns]

# %%
left_side_player = skills_stats.loc['Left Side Player']
left_side_player.head()
# Out:
#                  name  crossing  finishing  headingaccuracy  shortpassing  \
# id
# 179813      E. Cavani      70.0       89.0             89.0          78.0
# 167664     G. Higuaín      68.0       92.0             80.0          75.0
# 179844    Diego Costa      65.0       87.0             82.0          65.0
# 143076       A. Gómez      82.0       76.0             38.0          82.0
# 208093  Gerard Moreno      61.0       83.0             80.0          78.0
#
#         volleys  dribbling  curve  fkaccuracy  longpassing  ...  penalties  \
# id                                                          ...
# 179813     90.0       80.0   77.0        76.0         52.0  ...       85.0
# 167664     90.0       84.0   74.0        62.0         59.0  ...       70.0
# 179844     81.0       77.0   62.0        59.0         52.0  ...       75.0
# 143076     72.0       89.0   79.0        79.0         74.0  ...       72.0
# 208093     79.0       78.0   71.0        56.0         56.0  ...       73.0
#
#         composure  marking  standingtackle  slidingtackle  gkdiving  \
# id
# 179813       82.0     52.0            45.0           39.0      12.0
# 167664       86.0     35.0            22.0           18.0       5.0
# 179844       83.0     58.0            39.0           34.0      11.0
# 143076       84.0     50.0            30.0           34.0       8.0
# 208093       72.0     43.0            41.0           41.0      15.0
#
#         gkhandling  gkkicking  gkpositioning  gkreflexes
# id
# 179813         5.0       13.0           13.0        10.0
# 167664        12.0        7.0            5.0        10.0
# 179844        13.0       12.0            8.0        11.0
# 143076        11.0       12.0            9.0         6.0
# 208093        12.0        7.0           12.0        10.0
#
# [5 rows x 35 columns]

# %%
right_side_player = skills_stats.loc['Right Side Player']
right_side_player.head()
# Out:
#                   name  crossing  finishing  headingaccuracy  shortpassing  \
# id
# 176580       L. Suárez      77.0       93.0             77.0          82.0
# 41236   Z. Ibrahimović      73.0       86.0             83.0          79.0
# 167397          Falcao      55.0       86.0             89.0          79.0
# 199451   W. Ben Yedder      74.0       84.0             74.0          78.0
# 202685         S. Zaza      52.0       80.0             79.0          71.0
#
#         volleys  dribbling  curve  fkaccuracy  longpassing  ...  penalties  \
# id                                                          ...
# 176580     88.0       87.0   86.0        84.0         64.0  ...       85.0
# 41236      86.0       79.0   82.0        82.0         73.0  ...       89.0
# 167397     84.0       75.0   83.0        73.0         58.0  ...       81.0
# 199451     78.0       84.0   80.0        76.0         66.0  ...       76.0
# 202685     81.0       77.0   71.0        56.0         45.0  ...       79.0
#
#         composure  marking  standingtackle  slidingtackle  gkdiving  \
# id
# 176580       85.0     62.0            45.0           38.0      27.0
# 41236        90.0     28.0            37.0           24.0      13.0
# 167397       87.0     39.0            42.0           19.0      10.0
# 199451       84.0     34.0            33.0           26.0       6.0
# 202685       72.0     54.0            42.0           50.0       7.0
#
#         gkhandling  gkkicking  gkpositioning  gkreflexes
# id
# 176580        25.0       31.0           33.0        37.0
# 41236         15.0       10.0            9.0        12.0
# 167397        13.0        6.0            9.0         5.0
# 199451        13.0        9.0            7.0         7.0
# 202685        13.0        9.0            7.0         9.0
#
# [5 rows x 35 columns]

# %%
right_wing_back = skills_stats.loc['Right Wing Back']
right_wing_back.head()
# Out:
#                 name  crossing  finishing  headingaccuracy  shortpassing  \
# id
# 207862     M. Ginter      68.0       55.0             85.0          75.0
# 203605  P. Kadeřábek      86.0       28.0             71.0          77.0
# 180216    S. Coleman      82.0       61.0             69.0          78.0
# 197083  D. Caligiuri      83.0       72.0             65.0          78.0
# 221342  Pablo Maffeo      79.0       53.0             68.0          78.0
#
#         volleys  dribbling  curve  fkaccuracy  longpassing  ...  penalties  \
# id                                                          ...
# 207862     53.0       62.0   44.0        42.0         70.0  ...       67.0
# 203605     57.0       76.0   57.0        52.0         69.0  ...       54.0
# 180216     64.0       79.0   42.0        53.0         70.0  ...       55.0
# 197083     68.0       81.0   80.0        61.0         70.0  ...       83.0
# 221342     21.0       80.0   71.0        34.0         63.0  ...       37.0
#
#         composure  marking  standingtackle  slidingtackle  gkdiving  \
# id
# 207862       71.0     82.0            84.0           77.0      12.0
# 203605       78.0     72.0            79.0           76.0      10.0
# 180216       82.0     78.0            84.0           82.0       5.0
# 197083       76.0     70.0            72.0           68.0      12.0
# 221342       62.0     76.0            81.0           80.0      10.0
#
#         gkhandling  gkkicking  gkpositioning  gkreflexes
# id
# 207862        10.0        6.0            8.0        10.0
# 203605        11.0       14.0           13.0         7.0
# 180216        15.0       10.0           13.0         7.0
# 197083        10.0       13.0            6.0        14.0
# 221342         7.0       14.0           12.0        15.0
#
# [5 rows x 35 columns]

# %%
left_wing_back = skills_stats.loc['Left Wing Back']
left_wing_back.head()
# Out:
#              name  crossing  finishing  headingaccuracy  shortpassing  \
# id
# 200536  N. Schulz      83.0       48.0             54.0          78.0
# 223682    Granell      73.0       74.0             55.0          83.0
# 210455      Jonny      77.0       34.0             70.0          73.0
# 208334  J. Hector      79.0       55.0             71.0          78.0
# 214026  J. Mojica      79.0       62.0             55.0          78.0
#
#         volleys  dribbling  curve  fkaccuracy  longpassing  ...  penalties  \
# id                                                          ...
# 200536     49.0       79.0   59.0        42.0         70.0  ...       56.0
# 223682     56.0       76.0   80.0        76.0         79.0  ...       68.0
# 210455     44.0       73.0   60.0        54.0         59.0  ...       46.0
# 208334     51.0       74.0   65.0        65.0         74.0  ...       65.0
# 214026     43.0       78.0   74.0        68.0         70.0  ...       67.0
#
#         composure  marking  standingtackle  slidingtackle  gkdiving  \
# id
# 200536       75.0     74.0            76.0           77.0      13.0
# 223682       69.0     55.0            75.0           65.0       6.0
# 210455       70.0     77.0            79.0           82.0       7.0
# 208334       78.0     76.0            79.0           79.0       9.0
# 214026       69.0     67.0            78.0           79.0      13.0
#
#         gkhandling  gkkicking  gkpositioning  gkreflexes
# id
# 200536         9.0       15.0            7.0        14.0
# 223682        13.0       13.0           14.0        14.0
# 210455        10.0       12.0           10.0         6.0
# 208334        10.0       10.0           12.0        14.0
# 214026         8.0       14.0            9.0        15.0
#
# [5 rows x 35 columns]

# %%
center_forward = skills_stats.loc['Center Forward']
center_forward.head()
# Out:
#                 name  crossing  finishing  headingaccuracy  shortpassing  \
# id
# 198706  Luis Alberto      76.0       80.0             49.0          88.0
# 184431   S. Giovinco      72.0       80.0             34.0          80.0
# 205175      A. Milik      58.0       88.0             78.0          63.0
# 187072     L. Stindl      76.0       79.0             64.0          85.0
# 144622       Raffael      78.0       78.0             63.0          83.0
#
#         volleys  dribbling  curve  fkaccuracy  longpassing  ...  penalties  \
# id                                                          ...
# 198706     76.0       86.0   86.0        81.0         87.0  ...       56.0
# 184431     75.0       86.0   90.0        93.0         76.0  ...       73.0
# 205175     76.0       74.0   71.0        74.0         62.0  ...       79.0
# 187072     86.0       78.0   79.0        69.0         69.0  ...       80.0
# 144622     83.0       87.0   79.0        77.0         76.0  ...       72.0
#
#         composure  marking  standingtackle  slidingtackle  gkdiving  \
# id
# 198706       72.0     44.0            25.0           18.0       6.0
# 184431       82.0     23.0            29.0           28.0       6.0
# 205175       72.0     35.0            34.0           32.0       9.0
# 187072       83.0     59.0            61.0           50.0       7.0
# 144622       79.0     43.0            42.0           31.0      12.0
#
#         gkhandling  gkkicking  gkpositioning  gkreflexes
# id
# 198706         8.0        6.0           12.0        11.0
# 184431         3.0        6.0            3.0         3.0
# 205175        16.0       16.0           15.0         6.0
# 187072        10.0       13.0           11.0        12.0
# 144622        10.0        5.0           13.0        14.0
#
# [5 rows x 35 columns]

# %%
left_attacking_midfielder = skills_stats.loc['Left Attacking Midfielder']
left_attacking_midfielder.head()
# Out:
#                    name  crossing  finishing  headingaccuracy  shortpassing  \
# id
# 198710     J. Rodríguez      90.0       83.0             62.0          89.0
# 199434         D. Tadić      83.0       74.0             63.0          81.0
# 230408   Fabrio Farinha      75.0       65.0             58.0          77.0
# 230487  Leo Caldeirinha      75.0       72.0             77.0          73.0
# 230276  Nicolás Formido      74.0       57.0             71.0          75.0
#
#         volleys  dribbling  curve  fkaccuracy  longpassing  ...  penalties  \
# id                                                          ...
# 198710     90.0       85.0   89.0        86.0         83.0  ...       81.0
# 199434     73.0       85.0   83.0        76.0         77.0  ...       71.0
# 230408     66.0       77.0   70.0        62.0         74.0  ...       64.0
# 230487     61.0       75.0   79.0        76.0         64.0  ...       65.0
# 230276     55.0       74.0   81.0        76.0         73.0  ...       69.0
#
#         composure  marking  standingtackle  slidingtackle  gkdiving  \
# id
# 198710       87.0     52.0            41.0           44.0      15.0
# 199434       82.0     46.0            34.0           26.0      11.0
# 230408       76.0     23.0            56.0           48.0       8.0
# 230487       76.0     25.0            24.0           22.0      18.0
# 230276       72.0     18.0            29.0           21.0       9.0
#
#         gkhandling  gkkicking  gkpositioning  gkreflexes
# id
# 198710        15.0       15.0            5.0        14.0
# 199434        11.0       14.0            9.0        16.0
# 230408        15.0       11.0            7.0        15.0
# 230487        16.0       13.0           15.0        15.0
# 230276         8.0        8.0            7.0        12.0
#
# [5 rows x 35 columns]

# %%
right_attacking_midfielder = skills_stats.loc['Right Attacking Midfielder']
right_attacking_midfielder.head()
# Out:
#                   name  crossing  finishing  headingaccuracy  shortpassing  \
# id
# 193082     J. Cuadrado      80.0       67.0             58.0          80.0
# 208670       H. Ziyech      84.0       68.0             53.0          86.0
# 230465  Allan Bardinho      73.0       71.0             44.0          75.0
# 230483    Jacson Zonta      74.0       61.0             51.0          72.0
# 230267  Sebas Couteira      76.0       70.0             54.0          76.0
#
#         volleys  dribbling  curve  fkaccuracy  longpassing  ...  penalties  \
# id                                                          ...
# 193082     70.0       90.0   78.0        69.0         69.0  ...       65.0
# 208670     77.0       83.0   90.0        78.0         89.0  ...       73.0
# 230465     51.0       77.0   56.0        55.0         76.0  ...       72.0
# 230483     55.0       77.0   83.0        75.0         61.0  ...       71.0
# 230267     67.0       74.0   67.0        76.0         59.0  ...       57.0
#
#         composure  marking  standingtackle  slidingtackle  gkdiving  \
# id
# 193082       80.0     63.0            70.0           74.0       5.0
# 208670       83.0     52.0            66.0           36.0      11.0
# 230465       71.0     23.0            33.0           32.0      12.0
# 230483       66.0     31.0            21.0           22.0       8.0
# 230267       71.0     32.0            52.0           41.0      15.0
#
#         gkhandling  gkkicking  gkpositioning  gkreflexes
# id
# 193082         5.0       13.0            6.0         9.0
# 208670         7.0       11.0            8.0        14.0
# 230465         8.0       17.0            8.0        15.0
# 230483        14.0        9.0            9.0        12.0
# 230267        13.0       12.0           10.0         9.0
#
# [5 rows x 35 columns]
